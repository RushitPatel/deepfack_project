# %% [markdown]
# <a href="https://colab.research.google.com/github/RushitPatel/deepfack_project/blob/main/notebooks/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import mlflow
from deepfake_detection.deepfake_detection import DeepfakeDetectionSystem

# Engineering Rigour: Seed for reproducibility [cite: 82]
torch.manual_seed(42)
model = DeepfakeDetectionSystem().to(DEVICE)

with mlflow.start_run():
    mlflow.log_param("architecture", "Hybrid CNN-Transformer")
    mlflow.log_param("fusion", "Late Fusion")

    # Training loop code here...

    mlflow.log_metric("accuracy", final_accuracy)
    mlflow.pytorch.log_model(model, "model_checkpoint")
